# %%
library(datasets)
df <- read.csv("billonarios.csv", header = TRUE)

# %%
df
# Out:
#     pais                           nbillonarios logpibpc  logpob    gatt
# 1   United States                  469          10.786021 19.53285  60
# 2   Canada                          25          10.743365 17.31944   0
# 3   Bahamas, The                     0          10.072139 12.76093   0
# 4   Aruba                            0          10.223734 11.52628   0
# 5   Bermuda                          0          11.446847 11.08633   0
# 6   Cuba                             0           8.590968 16.23999   8
# 7   Haiti                            0           6.521256 16.08125  58
# 8   Dominican Republic               0           8.491694 16.09280  58
# 9   Jamaica                          0           8.542905 14.79831  45
# 10  Trinidad and Tobago              0           9.960371 14.09045  46
# 11  Barbados                         0           9.714175 12.53406  41
# 12  Dominica                         0           8.797091 11.16879  15
# ...

# %%
summary(glm(nbillonarios ~ logpibpc + logpob + gatt, df, family = poisson(link = "log")))
# Out:
# Call:
# glm(formula = nbillonarios ~ logpibpc + logpob + gatt, family = poisson(link = "log"),
#     data = df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -8.7615  -0.7585  -0.3775  -0.1010   9.0587
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -29.049541   0.638193 -45.518  < 2e-16 ***
# logpibpc      1.083856   0.035064  30.911  < 2e-16 ***
# logpob        1.171362   0.024156  48.491  < 2e-16 ***
# gatt          0.005968   0.001908   3.127  0.00176 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 5942.23  on 196  degrees of freedom
# Residual deviance:  669.95  on 193  degrees of freedom
# AIC: 885.08
#
# Number of Fisher Scoring iterations: 5
